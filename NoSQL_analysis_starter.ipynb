# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
from pymongo import MongoClient
import pandas as pd
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.collection_names)
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'uk_food'), 'collection_names')

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query =establishments.find({'scores.Hygiene':{'$eq':20}})
# Use count_documents to display the number of documents in the result
establishments.count_documents({'scores.Hygiene':{'$eq':20}})
# Display the first document in the results using pprint
pprint(establishments.find_one({'scores.Hygiene':{'$eq':20}}))
# Out:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('67d32cca31ad51a27e20ba20'),
#  'geocode': {'latitude': Decimal128('50.769705'),
#              'longitude': Decimal128('0.27694')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
# Convert the result to a Pandas DataFrame
data=pd.DataFrame(list(query))
# Display the number of rows in the DataFrame
len(data)
# Display the first 10 rows of the DataFrame
print(data.head(10))
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  67d32cca31ad51a27e20ba20   110681                  0
# 1  67d32cca31ad51a27e20bda5   612039                  0
# 2  67d32cca31ad51a27e20c0ac   730933                  0
# 3  67d32cca31ad51a27e20c29a   172735                  0
# 4  67d32cca31ad51a27e20c2a7   172953                  0
# 5  67d32ccb31ad51a27e20cc47   512854                  0
# 6  67d32ccb31ad51a27e20ce67  1537089                  0
# 7  67d32ccb31ad51a27e20e392   155648                  0
# 8  67d32ccb31ad51a27e20e7d7  1012883                  0
# 9  67d32ccb31ad51a27e20efe9   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# 5            12/00816/BUTH           Ashby's Butchers
# 6          22/00224/RESTUN  South Sea Express Cuisine
# 7              EH/00006058              Golden Palace
# 8         17/00110/MIXED/S             The Tulip Tree
# 9                    41811                      F & S
#
#                         BusinessType  BusinessTypeID           AddressLine1  \
# 0                    Caring Premises               5   5-6 Southfields Road
# 1                    Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/guest house            7842  53 Marine Parade East
# 3             Takeaway/sandwich shop            7844          4 High Street
# 4            Restaurant/Cafe/Canteen               1         5 South Street
# 5                  Retailers - other            4613   777 Southchurch Road
# 6            Restaurant/Cafe/Canteen               1    33 Alexandra Street
# 7             Takeaway/sandwich shop            7844          7 London Road
# 8            Restaurant/Cafe/Canteen               1          3 The Village
# 9                  Retailers - other            4613
#
#          AddressLine2 AddressLine3  ...  \
# 0          Eastbourne  East Sussex  ...
# 1  Walton-on-the-Naze        Essex  ...
# 2      Clacton On Sea        Essex  ...
# 3             Seaford  East Sussex  ...
# 4             Seaford  East Sussex  ...
# 5     Southend-On-Sea        Essex  ...
# 6     Southend-on-sea        Essex  ...
# 7            Rayleigh        Essex  ...
# 8       Chiddingstone         KENT  ...
# 9      81 Southernhay     Basildon  ...
#
#                       LocalAuthorityWebSite  \
# 0  http://www.eastbourne.gov.uk/foodratings
# 1             http://www.tendringdc.gov.uk/
# 2             http://www.tendringdc.gov.uk/
# 3       http://www.lewes-eastbourne.gov.uk/
# 4       http://www.lewes-eastbourne.gov.uk/
# 5                http://www.southend.gov.uk
# 6                http://www.southend.gov.uk
# 7                http://www.rochford.gov.uk
# 8              http://www.sevenoaks.gov.uk/
# 9                http://www.basildon.gov.uk
#
#               LocalAuthorityEmailAddress  \
# 0        Customerfirst@eastbourne.gov.uk
# 1             fhsadmin@tendringdc.gov.uk
# 2             fhsadmin@tendringdc.gov.uk
# 3    ehealth.ldc@lewes-eastbourne.gov.uk
# 4    ehealth.ldc@lewes-eastbourne.gov.uk
# 5    EnvironmentalHealth@southend.gov.uk
# 6    EnvironmentalHealth@southend.gov.uk
# 7       customerservices@rochford.gov.uk
# 8  environmental.health@sevenoaks.gov.uk
# 9                    ehs@basildon.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 1  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...        FHRS
# 2  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 3  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...        FHRS
# 4  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...        FHRS
# 5  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 6  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 7  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...        FHRS
# 8  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...        FHRS
# 9  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
#
#                                              geocode RightToReply  \
# 0      {'longitude': 0.27694, 'latitude': 50.769705}
# 1     {'longitude': 1.278721, 'latitude': 51.857536}
# 2      {'longitude': 1.15927, 'latitude': 51.789429}
# 3      {'longitude': 0.10202, 'latitude': 50.770885}
# 4     {'longitude': 0.101446, 'latitude': 50.770724}
# 5     {'longitude': 0.736349, 'latitude': 51.541448}
# 6   {'longitude': 0.7121671, 'latitude': 51.5350065}
# 7     {'longitude': 0.602364, 'latitude': 51.591515}
# 8  {'longitude': 0.146449998021126, 'latitude': 5...
# 9      {'longitude': 0.462307, 'latitude': 51.57005}
#
#       Distance NewRatingPending  \
# 0  4613.888288            False
# 1  4617.965824            False
# 2  4619.656144            False
# 3  4620.421725            False
# 4  4620.437179            False
# 5  4625.565258            False
# 6  4626.200132            False
# 7  4632.276890            False
# 8  4633.934041            False
# 9  4636.552523            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
# 5  [{'rel': 'self', 'href': 'https://api.ratings....
# 6  [{'rel': 'self', 'href': 'https://api.ratings....
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London in the LocalAuthorityName and has a RatingValue greater than or equal to 4.
query ={'$and':[{"LocalAuthorityName":{'$regex':".*London.*"}},{"RatingValue":{"$gte":4}}]}
establishments.find(query)

# Use count_documents to display the number of documents in the result
print(f'There are {establishments.count_documents(query)} establishments with London in the LocalAuthorityName and has a RatingValue greater than or equal to 4.')
# Display the first document in the results using pprint
pprint(establishments.find_one(query))
# Out:
# There are 33 establishments with London in the LocalAuthorityName and has a RatingValue greater than or equal to 4.
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('67d32ccb31ad51a27e20d43a'),
#  'geocode': {'latitude': Decimal128('51.369321'),
#              'longitude': Decimal128('0.508551')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/621707',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 10}}

# %%
# Convert the result to a Pandas DataFrame
df=pd.DataFrame(establishments.find(query))
# Display the number of rows in the DataFrame
print(len(df))
# Display the first 10 rows of the DataFrame
print(df.head(10))
# Out:
# 33
#                         _id   FHRSID  ChangesByServerID  \
# 0  67d32ccb31ad51a27e20d43a   621707                  0
# 1  67d32ccb31ad51a27e20d764  1130836                  0
# 2  67d32ccb31ad51a27e20e2af   293783                  0
# 3  67d32ccb31ad51a27e20f0ae  1315095                  0
# 4  67d32ccb31ad51a27e20f0b2   294474                  0
# 5  67d32ccb31ad51a27e20f7b6   294900                  0
# 6  67d32ccb31ad51a27e2118c5   293756                  0
# 7  67d32ccb31ad51a27e211c8f   878523                  0
# 8  67d32ccb31ad51a27e211ca5   294606                  0
# 9  67d32ccb31ad51a27e211ca6   293772                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# 3             PI/000036464  Coombs Catering t/a The Lock and Key
# 4             PI/000014647              Tilbury Seafarers Centre
# 5             PI/000019066                            Mv Valulla
# 6             PI/000002538                         Tereza Joanne
# 7             PI/000029844                      Brick Lane Brews
# 8             PI/000016185                              WH Smith
# 9             PI/000002585         The Nuance Group (UK) Limited
#
#               BusinessType  BusinessTypeID  \
# 0  Other catering premises            7841
# 1  Other catering premises            7841
# 2  Other catering premises            7841
# 3  Restaurant/Cafe/Canteen               1
# 4  Restaurant/Cafe/Canteen               1
# 5  Other catering premises            7841
# 6  Other catering premises            7841
# 7  Restaurant/Cafe/Canteen               1
# 8        Retailers - other            4613
# 9        Retailers - other            4613
#
#                                         AddressLine1  \
# 0         Oak Apple Farm Building 103 Sheernes Docks
# 1                                 Cherry Garden Pier
# 2                                         Ferry Road
# 3                                  Leslie Ford House
# 4                          Tenants Row Tilbury Docks
# 5  Reeds River Cruises LtdKings ReachRiver Thames...
# 6  Funcraft UK Ltd King George V Dock Woolwich Ma...
# 7                       Air side London City Airport
# 8                                London City Airport
# 9                  Duty Free Shop Passenger Terminal
#
#                            AddressLine2 AddressLine3  ...  \
# 0                           Sheppy Kent               ...
# 1      Cherry Garden Street Rotherhithe     Charlton  ...
# 2                  South Benfleet Essex               ...
# 3                               Tilbury     Charlton  ...
# 4                         Tilbury Essex               ...
# 5                                London               ...
# 6                                London               ...
# 7                                London               ...
# 8                     Silvertown London               ...
# 9  London City AirportRoyal DocksLondon               ...
#
#                                LocalAuthorityWebSite  \
# 0  http://www.cityoflondon.gov.uk/Corporation/hom...
# 1  http://www.cityoflondon.gov.uk/Corporation/hom...
# 2  http://www.cityoflondon.gov.uk/Corporation/hom...
# 3  http://www.cityoflondon.gov.uk/Corporation/hom...
# 4  http://www.cityoflondon.gov.uk/Corporation/hom...
# 5  http://www.cityoflondon.gov.uk/Corporation/hom...
# 6  http://www.cityoflondon.gov.uk/Corporation/hom...
# 7  http://www.cityoflondon.gov.uk/Corporation/hom...
# 8  http://www.cityoflondon.gov.uk/Corporation/hom...
# 9  http://www.cityoflondon.gov.uk/Corporation/hom...
#
#              LocalAuthorityEmailAddress  \
# 0  publicprotection@cityoflondon.gov.uk
# 1  publicprotection@cityoflondon.gov.uk
# 2  publicprotection@cityoflondon.gov.uk
# 3  publicprotection@cityoflondon.gov.uk
# 4  publicprotection@cityoflondon.gov.uk
# 5  publicprotection@cityoflondon.gov.uk
# 6  publicprotection@cityoflondon.gov.uk
# 7  publicprotection@cityoflondon.gov.uk
# 8  publicprotection@cityoflondon.gov.uk
# 9  publicprotection@cityoflondon.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 5, 'Structural': 10, 'ConfidenceIn...        FHRS
# 1  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 2  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 3  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 4  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 5  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 6  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 7  {'Hygiene': 10, 'Structural': 5, 'ConfidenceIn...        FHRS
# 8  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 9  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
#
#                                              geocode RightToReply  \
# 0     {'longitude': 0.508551, 'latitude': 51.369321}
# 1  {'longitude': 0.249255999922752, 'latitude': 5...
# 2     {'longitude': 0.561954, 'latitude': 51.543831}
# 3  {'longitude': 0.346336990594864, 'latitude': 5...
# 4     {'longitude': 0.346325, 'latitude': 51.464078}
# 5     {'longitude': 0.287555, 'latitude': 51.504071}
# 6     {'longitude': 0.069286, 'latitude': 51.501121}
# 7     {'longitude': 0.048006, 'latitude': 51.503733}
# 8  {'longitude': 0.0479655750095844, 'latitude': ...
# 9     {'longitude': 0.047966, 'latitude': 51.504112}
#
#       Distance NewRatingPending  \
# 0  4627.439468            False
# 1  4627.873179            False
# 2  4631.968418            False
# 3  4636.846754            False
# 4  4636.847650            False
# 5  4640.460834            False
# 6  4648.301822            False
# 7  4649.173485            False
# 8  4649.188850            False
# 9  4649.188826            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 5  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 6  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude =float(establishments.find_one({'BusinessName':'Penang Flavours'},{'geocode.latitude':1})['geocode']['latitude'].to_decimal().real)
longitude= float(establishments.find_one({'BusinessName':'Penang Flavours'},{'geocode.longitude':1})['geocode']['longitude'].to_decimal().real)

query ={'$and':[{'geocode.latitude':{'$lte':latitude+0.01,'$gte':latitude-0.01}},{'geocode.longitude':{'$gte':longitude-0.01,'$lte':longitude+0.01}},{'RatingValue':5}]}
sort = {'scores.Hygiene':1}
#limit =

# Print the results
for r in establishments.find(query).sort(sort):
    print(r)
# Out:
# {'_id': ObjectId('67d32ccb31ad51a27e2112e4'), 'FHRSID': 940026, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000177403', 'BusinessName': 'Abbi Wines', 'BusinessType': 'Retailers - other', 'BusinessTypeID': 4613, 'AddressLine1': '12 - 14 Lakedale Road', 'AddressLine2': '', 'AddressLine3': 'Plumstead', 'AddressLine4': 'Greenwich', 'PostCode': 'SE18 1PP', 'Phone': '', 'RatingValue': 5, 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2021-08-23T00:00:00', 'LocalAuthorityCode': '511', 'LocalAuthorityName': 'Greenwich', 'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0}, 'SchemeType': 'FHRS', 'geocode': {'longitude': Decimal128('0.0908895'), 'latitude': Decimal128('51.4871401')}, 'RightToReply': '', 'Distance': 4647.001583335365, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/940026'}]}
# {'_id': ObjectId('67d32ccb31ad51a27e211250'), 'FHRSID': 695223, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000178842', 'BusinessName': 'Iceland', 'BusinessType': 'Retailers - supermarkets/hypermarkets', 'BusinessTypeID': 7840, 'AddressLine1': '144 - 146 Plumstead High Street', 'AddressLine2': '', 'AddressLine3': 'Plumstead', 'AddressLine4': 'Greenwich', 'PostCode': 'SE18 1JQ', 'Phone': '', 'RatingValue': 5, 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2019-11-13T00:00:00', 'LocalAuthorityCode': '511', 'LocalAuthorityName': 'Greenwich', 'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 5}, 'SchemeType': 'FHRS', 'geocode': {'longitude': Decimal128('0.0924199968576431'), 'latitude': Decimal128('51.4871482849121')}, 'RightToReply': '', 'Distance': 4646.946071297699, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/695223'}]}
# {'_id': ObjectId('67d32ccb31ad51a27e211261'), 'FHRSID': 1380578, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': '14425', 'BusinessName': 'Howe and Co Fish and Chips - Van 17', 'BusinessType': 'Mobile caterer', 'BusinessTypeID': 7846, 'AddressLine1': 'Restaurant And Premises 107A Plumstead High Street', 'AddressLine2': '', 'AddressLine3': 'Plumstead', 'AddressLine4': 'Greenwich', 'PostCode': 'SE18 1SE', 'Phone': '', 'RatingValue': 5, 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2021-11-11T00:00:00', 'LocalAuthorityCode': '511', 'LocalAuthorityName': 'Greenwich', 'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0}, 'SchemeType': 'FHRS', 'geocode': {'longitude': Decimal128('0.0925370007753372'), 'latitude': Decimal128('51.4875335693359')}, 'RightToReply': '', 'Distance': 4646.95593107927, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/1380578'}]}
# {'_id': ObjectId('67d32ccb31ad51a27e21127e'), 'FHRSID': 694609, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000116619', 'BusinessName': 'Volunteer', 'BusinessType': 'Pub/bar/nightclub', 'BusinessTypeID': 7843, 'AddressLine1': '130 - 132 Plumstead High Street', 'AddressLine2': '', 'AddressLine3': 'Plumstead', 'AddressLine4': 'Greenwich', 'PostCode': 'SE18 1JQ', 'Phone': '', 'RatingValue': 5, 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2019-08-05T00:00:00', 'LocalAuthorityCode': '511', 'LocalAuthorityName': 'Greenwich', 'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0}, 'SchemeType': 'FHRS', 'geocode': {'longitude': Decimal128('0.09208'), 'latitude': Decimal128('51.4873437')}, 'RightToReply': '', 'Distance': 4646.965634598608, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/694609'}]}
# {'_id': ObjectId('67d32ccb31ad51a27e211297'), 'FHRSID': 695241, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000179088', 'BusinessName': 'Plumstead Manor Nursery', 'BusinessType': 'Caring Premises', 'BusinessTypeID': 5, 'AddressLine1': 'Plumstead Manor School Old Mill Road', 'AddressLine2': '', 'AddressLine3': 'Plumstead', 'AddressLine4': 'Greenwich', 'PostCode': 'SE18 1QG', 'Phone': '', 'RatingValue': 5, 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2021-06-16T00:00:00', 'LocalAuthorityCode': '511', 'LocalAuthorityName': 'Greenwich', 'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 5}, 'SchemeType': 'FHRS', 'geocode': {'longitude': Decimal128('0.0859939977526665'), 'latitude': Decimal128('51.481517791748')}, 'RightToReply': '', 'Distance': 4646.9740101340385, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/695241'}]}
# {'_id': ObjectId('67d32ccb31ad51a27e211299'), 'FHRSID': 694478, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000086506', 'BusinessName': 'Atlantic Fish Bar', 'BusinessType': 'Takeaway/sandwich shop', 'BusinessTypeID': 7844, 'AddressLine1': '35 Lakedale Road', 'AddressLine2': '', 'AddressLine3': 'Plumstead', 'AddressLine4': 'Greenwich', 'PostCode': 'SE18 1PR', 'Phone': '', 'RatingValue': 5, 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2021-06-16T00:00:00', 'LocalAuthorityCode': '511', 'LocalAuthorityName': 'Greenwich', 'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 5}, 'SchemeType': 'FHRS', 'geocode': {'longitude': Decimal128('0.0912164'), 'latitude': Decimal128('51.4867296')}, 'RightToReply': '', 'Distance': 4646.974611855838, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/694478'}]}
# {'_id': ObjectId('67d32ccb31ad51a27e21129c'), 'FHRSID': 909912, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000201100', 'BusinessName': 'Lumbini Grocery Ltd T/A Al-Iman', 'BusinessType': 'Retailers - other', 'BusinessTypeID': 4613, 'AddressLine1': '17 Lakedale Road', 'AddressLine2': '', 'AddressLine3': 'Plumstead', 'AddressLine4': 'Greenwich', 'PostCode': 'SE18 1PP', 'Phone': '', 'RatingValue': 5, 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2020-10-20T00:00:00', 'LocalAuthorityCode': '511', 'LocalAuthorityName': 'Greenwich', 'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0}, 'SchemeType': 'FHRS', 'geocode': {'longitude': Decimal128('0.0916256'), 'latitude': Decimal128('51.4871632')}, 'RightToReply': '', 'Distance': 4646.975587048333, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/909912'}]}
# {'_id': ObjectId('67d32ccb31ad51a27e2112b9'), 'FHRSID': 694482, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000086551', 'BusinessName': 'Greggs', 'BusinessType': 'Takeaway/sandwich shop', 'BusinessTypeID': 7844, 'AddressLine1': '6 Lakedale Road', 'AddressLine2': '', 'AddressLine3': 'Plumstead', 'AddressLine4': 'Greenwich', 'PostCode': 'SE18 1PP', 'Phone': '', 'RatingValue': 5, 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2021-06-23T00:00:00', 'LocalAuthorityCode': '511', 'LocalAuthorityName': 'Greenwich', 'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0}, 'SchemeType': 'FHRS', 'geocode': {'longitude': Decimal128('0.0912820026278496'), 'latitude': Decimal128('51.4871406555176')}, 'RightToReply': '', 'Distance': 4646.987290353701, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/694482'}]}
# {'_id': ObjectId('67d32ccb31ad51a27e2112bc'), 'FHRSID': 695204, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000177985', 'BusinessName': 'Tesco', 'BusinessType': 'Retailers - supermarkets/hypermarkets', 'BusinessTypeID': 7840, 'AddressLine1': '18 Lakedale Road', 'AddressLine2': '', 'AddressLine3': 'Plumstead', 'AddressLine4': 'Greenwich', 'PostCode': 'SE18 1PP', 'Phone': '', 'RatingValue': 5, 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2020-10-20T00:00:00', 'LocalAuthorityCode': '511', 'LocalAuthorityName': 'Greenwich', 'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0}, 'SchemeType': 'FHRS', 'geocode': {'longitude': Decimal128('0.0912820026278496'), 'latitude': Decimal128('51.4871406555176')}, 'RightToReply': '', 'Distance': 4646.987290353701, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/695204'}]}
# {'_id': ObjectId('67d32ccb31ad51a27e2112e1'), 'FHRSID': 1211907, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': '13217', 'BusinessName': 'Dosa & Sambal Express', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1, 'AddressLine1': '107A Plumstead High Street', 'AddressLine2': '', 'AddressLine3': 'Plumstead', 'AddressLine4': 'Greenwich', 'PostCode': '', 'Phone': '', 'RatingValue': 5, 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2020-07-09T00:00:00', 'LocalAuthorityCode': '511', 'LocalAuthorityName': 'Greenwich', 'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 5}, 'SchemeType': 'FHRS', 'geocode': {'longitude': Decimal128('0.091566'), 'latitude': Decimal128('51.4877576')}, 'RightToReply': '', 'Distance': 4646.999553676595, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/1211907'}]}
# {'_id': ObjectId('67d32ccb31ad51a27e211473'), 'FHRSID': 695460, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000186310', 'BusinessName': 'Bear Hugs Day Nursery', 'BusinessType': 'Caring Premises', 'BusinessTypeID': 
 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/723994'}]}
# {'_id': ObjectId('67d32ccb31ad51a27e2114a2'), 'FHRSID': 1250850, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': '13438', 'BusinessName': "Malai Restaurant/Ghandi's/Sweet Sensationz/JusBoba", 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1, 'AddressLine1': '8 Plumstead High Street', 'AddressLine2': '', 'AddressLine3': 'Plumstead', 'AddressLine4': 'Greenwich', 'PostCode': 'SE18 1SN', 'Phone': '', 'RatingValue': 5, 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2021-06-23T00:00:00', 'LocalAuthorityCode': '511', 'LocalAuthorityName': 'Greenwich', 'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 'scores': {'Hygiene': 5, 'Structural': 0, 'ConfidenceInManagement': 0}, 'SchemeType': 'FHRS', 'geocode': {'longitude': Decimal128('0.0859184'), 'latitude': Decimal128('51.489315')}, 'RightToReply': '', 'Distance': 4647.2625988326445, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/1250850'}]}
# {'_id': ObjectId('67d32ccb31ad51a27e2114c3'), 'FHRSID': 694838, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000154235', 'BusinessName': 'Plumstead Radical Club', 'BusinessType': 'Pub/bar/nightclub', 'BusinessTypeID': 7843, 'AddressLine1': 'Plumstead Radical Club 83 - 88 Walmer Terrace', 'AddressLine2': '', 'AddressLine3': 'Plumstead', 'AddressLine4': 'Greenwich', 'PostCode': 'SE18 7DZ', 'Phone': '', 'RatingValue': 5, 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2020-09-05T00:00:00', 'LocalAuthorityCode': '511', 'LocalAuthorityName': 'Greenwich', 'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5}, 'SchemeType': 'FHRS', 'geocode': {'longitude': Decimal128('0.084697000682354'), 'latitude': Decimal128('51.4893112182617')}, 'RightToReply': '', 'Distance': 4647.30700092017, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/694838'}]}
# {'_id': ObjectId('67d32ccb31ad51a27e2114d5'), 'FHRSID': 694128, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000020389', 'BusinessName': 'Nisa Local', 'BusinessType': 'Retailers - other', 'BusinessTypeID': 4613, 'AddressLine1': '15 Brewery Road', 'AddressLine2': '', 'AddressLine3': 'Plumstead', 'AddressLine4': 'Greenwich', 'PostCode': 'SE18 7PX', 'Phone': '', 'RatingValue': 5, 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2020-09-05T00:00:00', 'LocalAuthorityCode': '511', 'LocalAuthorityName': 'Greenwich', 'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 'scores': {'Hygiene': 5, 'Structural': 0, 'ConfidenceInManagement': 0}, 'SchemeType': 'FHRS', 'geocode': {'longitude': Decimal128('0.0809311'), 'latitude': Decimal128('51.4861922')}, 'RightToReply': '', 'Distance': 4647.330009842794, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/694128'}]}
# {'_id': ObjectId('67d32ccb31ad51a27e21166f'), 'FHRSID': 1385142, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': '14492', 'BusinessName': 'Heronsgate Primary School Royal Arsenal Campus', 'BusinessType': 'School/college/university', 'BusinessTypeID': 7845, 'AddressLine1': 'Heronsgate Primary School Burrage Grove Campus Burrage Grove', 'AddressLine2': '', 'AddressLine3': 'Plumstead', 'AddressLine4': 'Greenwich', 'PostCode': 'SE18 7LJ', 'Phone': '', 'RatingValue': 5, 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2021-10-14T00:00:00', 'LocalAuthorityCode': '511', 'LocalAuthorityName': 'Greenwich', 'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 0}, 'SchemeType': 'FHRS', 'geocode': {'longitude': Decimal128('0.074074998497963'), 'latitude': Decimal128('51.4898490905762')}, 'RightToReply': '', 'Distance': 4647.714088390572, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/1385142'}]}
# {'_id': ObjectId('67d32ccb31ad51a27e2114db'), 'FHRSID': 1300359, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': '13959', 'BusinessName': 'Brew Station', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1, 'AddressLine1': '158A Plumstead Road', 'AddressLine2': '', 'AddressLine3': 'Woolwich', 'AddressLine4': 'Greenwich', 'PostCode': 'SE18 7DY', 'Phone': '', 'RatingValue': 5, 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2020-12-18T00:00:00', 'LocalAuthorityCode': '511', 'LocalAuthorityName': 'Greenwich', 'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 'scores': {'Hygiene': 5, 'Structural': 0, 'ConfidenceInManagement': 5}, 'SchemeType': 'FHRS', 'geocode': {'longitude': Decimal128('0.0846755'), 'latitude': Decimal128('51.4899426')}, 'RightToReply': '', 'Distance': 4647.330930511907, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/1300359'}]}
# {'_id': ObjectId('67d32ccb31ad51a27e21167d'), 'FHRSID': 1156702, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': '12845', 'BusinessName': 'PLOT Roasting', 'BusinessType': 'Other catering premises', 'BusinessTypeID': 7841, 'AddressLine1': 'Unit 38 The I O Centre Armstrong Road', 'AddressLine2': '', 'AddressLine3': 'Woolwich', 'AddressLine4': 'Greenwich', 'PostCode': 'SE18 6RS', 'Phone': '', 'RatingValue': 5, 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2020-10-16T00:00:00', 'LocalAuthorityCode': '511', 'LocalAuthorityName': 'Greenwich', 'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5}, 'SchemeType': 'FHRS', 'geocode': {'longitude': Decimal128('0.0770593'), 'latitude': Decimal128('51.4935863')}, 'RightToReply': '', 'Distance': 4647.742227445188, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/1156702'}]}
# {'_id': ObjectId('67d32ccb31ad51a27e2114a7'), 'FHRSID': 694625, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000117239', 'BusinessName': 'Mr Uncles Kebab', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1, 'AddressLine1': '6 Plumstead High Street', 'AddressLine2': '', 'AddressLine3': 'Plumstead', 'AddressLine4': 'Greenwich', 'PostCode': 'SE18 1SN', 'Phone': '', 'RatingValue': 5, 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2021-10-07T00:00:00', 'LocalAuthorityCode': '511', 'LocalAuthorityName': 'Greenwich', 'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5}, 'SchemeType': 'FHRS', 'geocode': {'longitude': Decimal128('0.0858325'), 'latitude': Decimal128('51.4893255')}, 'RightToReply': '', 'Distance': 4647.2661162513805, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/694625'}]}
# {'_id': ObjectId('67d32ccb31ad51a27e21122b'), 'FHRSID': 1069652, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000206841', 'BusinessName': 'TIWA N TIWA African Restaurant Ltd', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1, 'AddressLine1': '152 Plumstead High Street', 'AddressLine2': '', 'AddressLine3': 'Plumstead', 'AddressLine4': 'Greenwich', 'PostCode': 'SE18 1JQ', 'Phone': '', 'RatingValue': 5, 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2020-10-24T00:00:00', 'LocalAuthorityCode': '511', 'LocalAuthorityName': 'Greenwich', 'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5}, 'SchemeType': 'FHRS', 'geocode': {'longitude': Decimal128('0.0927429'), 'latitude': Decimal128('51.4870351')}, 'RightToReply': '', 'Distance': 4646.930146257832, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/1069652'}]}
# {'_id': ObjectId('67d32ccb31ad51a27e2115ba'), 'FHRSID': 947998, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000202511', 'BusinessName': 'GMT Kitchen and Cafe', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1, 'AddressLine1': '95 Plumstead Road', 'AddressLine2': '', 'AddressLine3': 'Woolwich', 'AddressLine4': 'Greenwich', 'PostCode': 'SE18 7DQ', 'Phone': '', 'RatingValue': 5, 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2022-03-23T00:00:00', 'LocalAuthorityCode': '511', 'LocalAuthorityName': 'Greenwich', 'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 0}, 'SchemeType': 'FHRS', 'geocode': {'longitude': Decimal128('0.0787421'), 'latitude': Decimal128('51.4903331')}, 'RightToReply': '', 'Distance': 4647.56162094585, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/947998'}]}

# %%
# Convert result to Pandas DataFrame
df=pd.DataFrame(establishments.find(query).sort(sort))
print(df)
# Out:
#                          _id   FHRSID  ChangesByServerID  \
# 0   67d32ccb31ad51a27e2112e4   940026                  0
# 1   67d32ccb31ad51a27e211250   695223                  0
# 2   67d32ccb31ad51a27e211261  1380578                  0
# 3   67d32ccb31ad51a27e21127e   694609                  0
# 4   67d32ccb31ad51a27e211297   695241                  0
# ..                       ...      ...                ...
# 82  67d32ccb31ad51a27e2114db  1300359                  0
# 83  67d32ccb31ad51a27e21167d  1156702                  0
# 84  67d32ccb31ad51a27e2114a7   694625                  0
# 85  67d32ccb31ad51a27e21122b  1069652                  0
# 86  67d32ccb31ad51a27e2115ba   947998                  0
#
#    LocalAuthorityBusinessID                         BusinessName  \
# 0              PI/000177403                           Abbi Wines
# 1              PI/000178842                              Iceland
# 2                     14425  Howe and Co Fish and Chips - Van 17
# 3              PI/000116619                            Volunteer
# 4              PI/000179088              Plumstead Manor Nursery
# ..                      ...                                  ...
# 82                    13959                         Brew Station
# 83                    12845                        PLOT Roasting
# 84             PI/000117239                      Mr Uncles Kebab
# 85             PI/000206841   TIWA N TIWA African Restaurant Ltd
# 86             PI/000202511                 GMT Kitchen and Cafe
#
#                              BusinessType  BusinessTypeID  \
# 0                       Retailers - other            4613
# 1   Retailers - supermarkets/hypermarkets            7840
# 2                          Mobile caterer            7846
# 3                       Pub/bar/nightclub            7843
# 4                         Caring Premises               5
# ..                                    ...             ...
# 82                Restaurant/Cafe/Canteen               1
# 83                Other catering premises            7841
# 84                Restaurant/Cafe/Canteen               1
# 85                Restaurant/Cafe/Canteen               1
# 86                Restaurant/Cafe/Canteen               1
#
#                                          AddressLine1 AddressLine2  \
# 0                               12 - 14 Lakedale Road
# 1                     144 - 146 Plumstead High Street
# 2   Restaurant And Premises 107A Plumstead High St...
# 3                     130 - 132 Plumstead High Street
# 4                Plumstead Manor School Old Mill Road
# ..                                                ...          ...
# 82                                158A Plumstead Road
# 83              Unit 38 The I O Centre Armstrong Road
# 84                            6 Plumstead High Street
# 85                          152 Plumstead High Street
# 86                                  95 Plumstead Road
#
#    AddressLine3  ...             LocalAuthorityWebSite  \
# 0     Plumstead  ...  http://www.royalgreenwich.gov.uk
# 1     Plumstead  ...  http://www.royalgreenwich.gov.uk
# 2     Plumstead  ...  http://www.royalgreenwich.gov.uk
# 3     Plumstead  ...  http://www.royalgreenwich.gov.uk
# 4     Plumstead  ...  http://www.royalgreenwich.gov.uk
# ..          ...  ...                               ...
# 82     Woolwich  ...  http://www.royalgreenwich.gov.uk
# 83     Woolwich  ...  http://www.royalgreenwich.gov.uk
# 84    Plumstead  ...  http://www.royalgreenwich.gov.uk
# 85    Plumstead  ...  http://www.royalgreenwich.gov.uk
# 86     Woolwich  ...  http://www.royalgreenwich.gov.uk
#
#       LocalAuthorityEmailAddress  \
# 0   health@royalgreenwich.gov.uk
# 1   health@royalgreenwich.gov.uk
# 2   health@royalgreenwich.gov.uk
# 3   health@royalgreenwich.gov.uk
# 4   health@royalgreenwich.gov.uk
# ..                           ...
# 82  health@royalgreenwich.gov.uk
# 83  health@royalgreenwich.gov.uk
# 84  health@royalgreenwich.gov.uk
# 85  health@royalgreenwich.gov.uk
# 86  health@royalgreenwich.gov.uk
#
#                                                scores  SchemeType  \
# 0   {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 1   {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 2   {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 3   {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 4   {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# ..                                                ...         ...
# 82  {'Hygiene': 5, 'Structural': 0, 'ConfidenceInM...        FHRS
# 83  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...        FHRS
# 84  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...        FHRS
# 85  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...        FHRS
# 86  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...        FHRS
#
#                                               geocode RightToReply  \
# 0    {'longitude': 0.0908895, 'latitude': 51.4871401}
# 1   {'longitude': 0.0924199968576431, 'latitude': ...
# 2   {'longitude': 0.0925370007753372, 'latitude': ...
# 3      {'longitude': 0.09208, 'latitude': 51.4873437}
# 4   {'longitude': 0.0859939977526665, 'latitude': ...
# ..                                                ...          ...
# 82   {'longitude': 0.0846755, 'latitude': 51.4899426}
# 83   {'longitude': 0.0770593, 'latitude': 51.4935863}
# 84   {'longitude': 0.0858325, 'latitude': 51.4893255}
# 85   {'longitude': 0.0927429, 'latitude': 51.4870351}
# 86   {'longitude': 0.0787421, 'latitude': 51.4903331}
#
#        Distance NewRatingPending  \
# 0   4647.001583            False
# 1   4646.946071            False
# 2   4646.955931            False
# 3   4646.965635            False
# 4   4646.974010            False
# ..          ...              ...
# 82  4647.330931            False
# 83  4647.742227            False
# 84  4647.266116            False
# 85  4646.930146            False
# 86  4647.561621            False
#
#                                                  meta  \
# 0   {'dataSource': None, 'extractDate': '0001-01-0...
# 1   {'dataSource': None, 'extractDate': '0001-01-0...
# 2   {'dataSource': None, 'extractDate': '0001-01-0...
# 3   {'dataSource': None, 'extractDate': '0001-01-0...
# 4   {'dataSource': None, 'extractDate': '0001-01-0...
# ..                                                ...
# 82  {'dataSource': None, 'extractDate': '0001-01-0...
# 83  {'dataSource': None, 'extractDate': '0001-01-0...
# 84  {'dataSource': None, 'extractDate': '0001-01-0...
# 85  {'dataSource': None, 'extractDate': '0001-01-0...
# 86  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                 links
# 0   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 1   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4   [{'rel': 'self', 'href': 'http://api.ratings.f...
# ..                                                ...
# 82  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 83  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 84  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 85  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 86  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [87 rows x 28 columns]

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that:
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest
match={'$match':{'scores.Hygiene':0}}
group={'$group':{'_id':"$LocalAuthorityName",'count':{'$sum':1}}}
sort={'$sort':{'count':-1}}
pipeline=[match,group,sort]
# Print the number of documents in the result
print(len(list(establishments.aggregate(pipeline))))
# Print the first 10 results
print(list(establishments.aggregate(pipeline))[:10])
# Out:
# 55
# [{'_id': 'Thanet', 'count': 1130}, {'_id': 'Greenwich', 'count': 882}, {'_id': 'Maidstone', 'count': 713}, {'_id': 'Newham', 'count': 711}, {'_id': 'Swale', 'count': 686}, {'_id': 'Chelmsford', 'count': 680}, {'_id': 'Medway', 'count': 672}, {'_id': 'Bexley', 'count': 607}, {'_id': 'Southend-On-Sea', 'count': 586}, {'_id': 'Tendring', 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame
hygiene_df=pd.DataFrame(list(establishments.aggregate(pipeline)))
# Display the number of rows in the DataFrame
len(hygiene_df)
# Display the first 10 rows of the DataFrame
hygiene_df.head(10)
# Out:
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
