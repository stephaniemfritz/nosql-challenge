# %%
from splinter import Browser
from bs4 import BeautifulSoup

# %%
# Open a Chrome window using Splinter
browser = Browser('chrome')

# %%
# Visit the URL
url = "https://globalvoices.org/page/2/"
browser.visit(url)

# Parse the HTML
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
# Close the dialogue box
browser.links.find_by_partial_text("Close").click()

# %%
# Create a function to perform the web scraping
def get_summary():
    # Collect the HTML from the browser
    html = browser.html

    # Parse the HTML with Beautiful Soup
    soup = BeautifulSoup(html, 'html.parser')

    # Save the main area of the web page to a variable
    main_area = soup.find("div", class_="post-archive-container")

    # Find all the articles in the main area of the web page
    articles = main_area.find_all("div", class_="gv-promo-card-text")

    # Create an empty list to hold summaries
    summary_list = []

    # Loop through the articles
    for article in articles:
        # Collect the article title
        header = article.find("h3", class_="post-title").text.strip()

        # Collect the article date
        date = article.find("span", class_="datestamp")["title"]

        # Remove the underscore from the date
        date = date.replace('_', '')

        # Create the summary dictionary
        summary_dict = {
            "header": header,
            "date": date
        }

        # Append the summary dictionary to the list
        summary_list.append(summary_dict)

    # Return the list of summaries
    return summary_list

# %%
# Create a loop to collect the article summaries and click to the older article pages 5 times
articles_list = []
for _ in range(5):
    summary = get_summary()
    articles_list.extend(summary)
    browser.links.find_by_partial_text("Older stories").click()

# %%
# Print the articles list
articles_list
# Out:
# [{'header': 'Precision agriculture: A passion for Togolese PhD student Aicha Biaou',
#   'date': '4 09 2024'},
#  {'header': 'China’s top nationalist influencer Hu Xijin silenced for over a month, but very few miss him',
#   'date': '4 09 2024'},
#  {'header': 'Georgian Dream Party vows to ban opposition if they win parliamentary majority',
#   'date': '3 09 2024'},
#  {'header': 'Pacific leaders’ statement removes Taiwan reference after China complaint',
#   'date': '3 09 2024'},
#  {'header': 'Mongolia’s new minister is determined to reform its education sector',
#   'date': '3 09 2024'},
#  {'header': 'Line of conflict shifts from the Donbas in Ukraine to Mali in the Sahel',
#   'date': '3 09 2024'},
#  {'header': 'Cairns fair showcases northern Queensland Indigenous art with style',
#   'date': '2 09 2024'},
#  {'header': 'The election dance in Azerbaijan: Carousel voting and ballot stuffing',
#   'date': '2 09 2024'},
#  {'header': 'New Russian-style law censors mentioning LGBTQ+ in the Bulgarian school system',
#   'date': '2 09 2024'},
#  {'header': 'Despite promises, Azerbaijani people continue to face water shortages',
#   'date': '1 09 2024'},
#  {'header': 'Hong Kong NGOs for sexual minorities suffer government funding cuts and pressure',
#   'date': '1 09 2024'},
#  {'header': 'Messages from two African disability activists to world leaders ahead of the UN Summit of the Future',
#   'date': '1 09 2024'},
#  {'header': "Guyana's Sir Shridath Ramphal, esteemed international statesman, dies at 95",
#   'date': '31 08 2024'},
#  {'header': 'Bangladeshis help out in flood-affected communities',
#   'date': '31 08 2024'},
#  {'header': 'Azerbaijan clears out critics ahead of COP29',
#   'date': '30 08 2024'},
#  {'header': 'Listen to the voices of Afro-Colombian trans women who speak about their powerful connections to the Pacific rivers',
#   'date': '30 08 2024'},
#  {'header': 'The impact of unpredictable rainfall and flooding on agriculture and food security in Kenya',
#   'date': '30 08 2024'},
#  {'header': 'What online narratives tell us about the aftermath of the election in Venezuela',
#   'date': '30 08 2024'},
#  {'header': 'Two Hong Kong journalists found guilty of sedition after a 2-year trial',
#   'date': '30 08 2024'},
#  {'header': 'Top officials in Kazakhstan dodge independent journalists',
#   'date': '29 08 2024'},
#  {'header': 'Séverin Ayao Kansa: Togo’s only chance of success at the 2024 Paris Paralympic Games',
#   'date': '29 08 2024'},
#  {'header': "Jamaica's finance minister’s appointment as deputy managing director of the IMF, a first for the region, brings plaudits and some local concerns",
#   'date': '28 08 2024'},
#  {'header': 'Tech giants criticized for silencing Pro-Palestinian narratives',
#   'date': '28 08 2024'},
#  {'header': 'Everything you should know about the Nigeria vs South Africa ‘online ride-hailing war’',
#   'date': '27 08 2024'},
#  {'header': 'Central Asians display unprecedented regional solidarity at the Paris Olympics',
#   'date': '27 08 2024'},
#  {'header': 'From Myanmar to Thailand: Displaced journalists tell their stories',
#   'date': '27 08 2024'},
#  {'header': 'Lives on the line in the Himalayan mountains',
#   'date': '27 08 2024'},
#  {'header': 'Citizens place blame on India as flash floods ravage Bangladesh',
#   'date': '26 08 2024'},
#  {'header': 'Through the lens of Czech-British photographer Liba Taylor: The power of photography',
#   'date': '26 08 2024'},
#  {'header': 'Madagascar: Hyperinflation could trigger a social implosion',
#   'date': '26 08 2024'},
#  {'header': "‘Nionsologie': A term used in DRC to describe those who profess to know it all",
#   'date': '26 08 2024'},
#  {'header': "Ecuador's conflicts of power: Was there an ‘attempted coup d'état’ or ‘political gender violence'?",
#   'date': '23 08 2024'},
#  {'header': 'From revolution to exile: The journey of Iranian activist Nasrin Bassiri',
#   'date': '23 08 2024'},
#  {'header': 'Hong Kong’s neon glow dims, symbolising the end of an era',
#   'date': '22 08 2024'},
#  {'header': 'Coastal villages struggle to recover after oil spill disaster near Philippine capital',
#   'date': '22 08 2024'},
#  {'header': 'What are the controversies over Hong Kong’s latest cybersecurity bill?',
#   'date': '22 08 2024'},
#  {'header': 'How LGBTQ+ people live in Russia after being labeled an extremist community',
#   'date': '22 08 2024'},
#  {'header': 'From uprootedness to artistic expression: An interview with Cameroonian artist\xa0Salifou Lindou',
#   'date': '22 08 2024'},
#  {'header': 'Belarusian stand-up comedian who compared Lukashenka to a sparrow is accused of defamation',
#   'date': '22 08 2024'},
#  {'header': 'The unique sounds of South Africa are a reminder of the country’s traditions, struggle, and resilience',
#   'date': '21 08 2024'},
#  {'header': 'What happened to Nigeria at the Paris Olympics?',
#   'date': '21 08 2024'},
#  {'header': 'Venezuelan women say polarization in Venezuela is over',
#   'date': '21 08 2024'},
#  {'header': '‘Buddha is with us!’ How the war in Ukraine has changed Russian Buddhism',
#   'date': '21 08 2024'},
#  {'header': 'Expectations ahead of parliamentary election in Azerbaijan are grim: Interview with an independent candidate',
#   'date': '21 08 2024'},
#  {'header': 'One hundred Turkish lira for your data: How Turkish citizens lost all expectations of data security and privacy',
#   'date': '21 08 2024'},
#  {'header': 'How online disinformation fuels religious, ethnic and sociopolitical tensions during Bangladesh’s regime change',
#   'date': '20 08 2024'},
#  {'header': 'Being in exile is to struggle to say ‘here’',
#   'date': '20 08 2024'},
#  {'header': 'Are 90 percent of Kenyans homophobic?', 'date': '20 08 2024'},
#  {'header': 'Starlink in Sudan: A lifeline or war facilitator?',
#   'date': '20 08 2024'},
#  {'header': 'Fear and intolerance: The impact of blasphemy allegations on Pakistan’s minorities',
#   'date': '20 08 2024'},
#  {'header': 'The passing of an iconic Guyanese singer sparks patriotic feelings, as border dispute with Venezuela drags on',
#   'date': '20 08 2024'},
#  {'header': "‘We have nothing except our hearts, and our minds': Vietnamese activist sentenced to five years in prison",
#   'date': '19 08 2024'},
#  {'header': "Venezuelans use AI avatars and Instagram Live to fight back Maduro's repression",
#   'date': '19 08 2024'},
#  {'header': 'Meet the US boxer who laid the foundation of boxing in Uzbekistan',
#   'date': '19 08 2024'},
#  {'header': 'Website blocking in India: One arrow for all',
#   'date': '19 08 2024'},
#  {'header': 'African Union: Concerns grow on African continent over the spread of mpox',
#   'date': '19 08 2024'},
#  {'header': 'Some historic moments for Africa at the 2024 Olympic Games',
#   'date': '19 08 2024'},
#  {'header': 'Floods in Libya a month before the anniversary of the Derna floods raise fears',
#   'date': '19 08 2024'},
#  {'header': 'Life in Gaza is even harder than it appears on screen',
#   'date': '16 08 2024'},
#  {'header': 'In Turkey, a street interview lands a citizen in jail',
#   'date': '15 08 2024'},
#  {'header': 'Turkey is committed to undermining NATO', 'date': '15 08 2024'},
#  {'header': "LIVE on August 27: Media and information literacy in Europe's regional languages",
#   'date': '15 08 2024'},
#  {'header': "New laws, old shadows: India's criminal legislation overhaul",
#   'date': '14 08 2024'},
#  {'header': 'Solar power plant in rural Pakistan acquires land without consent',
#   'date': '14 08 2024'},
#  {'header': 'The two deaths of the ‘Brazilian DSA’', 'date': '14 08 2024'},
#  {'header': 'Taiwan embraces Olympic gold medal boxer Lin Yu-ting amid unwarranted gender controversy',
#   'date': '14 08 2024'},
#  {'header': 'Internet shutdowns in Sudan allow the bypass of regulations',
#   'date': '14 08 2024'},
#  {'header': 'Pro-democracy activists in Zimbabwe are being prosecuted for ‘public disorder’',
#   'date': '14 08 2024'},
#  {'header': 'In a blow to democracy, Thai court dissolves main opposition party',
#   'date': '13 08 2024'},
#  {'header': 'After the SID4 conference in Antigua & Barbuda, ‘small islands’ fight to maintain ‘special case’ status at the UN',
#   'date': '13 08 2024'},
#  {'header': 'Venezuelan migrant in Colombia: ‘I dream of returning to rebuild our country’',
#   'date': '13 08 2024'},
#  {'header': "Interview with Korean-Ukrainian podcaster Oleksandr Shyn about Taiwan's linguistic landscape",
#   'date': '13 08 2024'},
#  {'header': "Bangladesh 2.0: Youth-led movement ends Sheikh Hasina's 16-year rule, seeks reform",
#   'date': '12 08 2024'},
#  {'header': 'Why is most scholastic research never read by those it most benefits —\xa0and can we change it?',
#   'date': '12 08 2024'},
#  {'header': 'US diplomats’ memoirs offer candid tales of Central Asian history',
#   'date': '12 08 2024'},
#  {'header': 'Rare Olympic Games coverage opportunity for African journalists: An interview with Daniel Dodjagni',
#   'date': '12 08 2024'},
#  {'header': 'African journalist perspectives on 2024 Paris Olympic Games',
#   'date': '12 08 2024'},
#  {'header': "World Steelpan Day acknowledges Trinidad & Tobago's national instrument, while a new film on panyards shows its power and potential",
#   'date': '11 08 2024'},
#  {'header': 'Barbados’ decision to give outstanding centenarians its stamp of approval is just one way the country honours its elders',
#   'date': '10 08 2024'},
#  {'header': 'Post-election repression in Venezuela: Authorities target human rights defenders and humanitarian workers',
#   'date': '9 08 2024'},
#  {'header': 'Covering Gaza: The deadliest war for journalists',
#   'date': '9 08 2024'},
#  {'header': 'Dear international left: Stop telling Venezuelans what to think',
#   'date': '9 08 2024'},
#  {'header': 'China helped Cameroon build drinking water infrastructure. Is it a debt crisis or developmental aid?',
#   'date': '8 08 2024'},
#  {'header': 'Hip-hop artist recalls her husband’s execution in Myanmar',
#   'date': '8 08 2024'},
#  {'header': 'Women are paying the ultimate price in Cameroon’s armed conflict',
#   'date': '8 08 2024'},
#  {'header': 'Malaysia’s social media licensing rule: Online protection or censorship?',
#   'date': '8 08 2024'},
#  {'header': "Can Hong Kong's achievement in the Olympics revive the city's spirit?",
#   'date': '8 08 2024'},
#  {'header': 'After some disappointments, a record-breaking discus throw gives Jamaicans their first gold medal of the Paris Olympic Games',
#   'date': '8 08 2024'},
#  {'header': 'Senegalese parliamentarian Guy Marius Sagna defends the people in ECOWAS parliament',
#   'date': '8 08 2024'},
#  {'header': 'Azerbaijan: Continued arrests and allegations of mass torture ahead of COP29',
#   'date': '8 08 2024'},
#  {'header': 'Hong Kong secondary students may soon be schooled in ‘Xi Jinping Thought’',
#   'date': '8 08 2024'},
#  {'header': "Bestselling writer Paulo Coelho remembers his torture under Brazil's military dictatorship",
#   'date': '7 08 2024'},
#  {'header': 'Sri Lanka elections: Will the real Wickremesinghe, Premadasa and Dissanayake please stand up?',
#   'date': '7 08 2024'},
#  {'header': "The Venezuela of Maduro, the inconvenient sister of Latin America's left",
#   'date': '7 08 2024'},
#  {'header': 'With no local press, a Brazilian town relies on word-of-mouth to inform people',
#   'date': '6 08 2024'},
#  {'header': 'Activist: ‘It is not Russophobia, but a lack of awareness among employees’',
#   'date': '6 08 2024'},
#  {'header': 'Australian journalists strike for better pay and working conditions',
#   'date': '6 08 2024'},
#  {'header': "After he spent 13 years in jail on a murder charge, what does dancehall deejay Vybz Kartel's release say about Jamaica's judicial system?",
#   'date': '4 08 2024'},
#  {'header': "Resistance art as a weapon in Bangladesh's ongoing student movement",
#   'date': '4 08 2024'},
#  {'header': 'Belarusians in exile dismayed that no Belarusian was included in the prisoner swap',
#   'date': '4 08 2024'},
#  {'header': 'Two women athletes have just earned St. Lucia and Dominica their first ever Olympic medals',
#   'date': '4 08 2024'},
#  {'header': 'Vaping loopholes are endangering children and the environment in Nigeria and Burkina Faso',
#   'date': '3 08 2024'},
#  {'header': 'Turkey blocks access to Instagram', 'date': '2 08 2024'},
#  {'header': 'The Caribbean marks Emancipation Day', 'date': '2 08 2024'},
#  {'header': 'How the war in Ukraine prompted an exodus of Chechens\xa0from\xa0Russia',
#   'date': '2 08 2024'}]

# %%
# Import Pandas
import pandas as pd

# Convert the articles list to a Pandas DataFrame
df = pd.DataFrame(articles_list)
df.head()
# Out:
#                                               header       date
# 0  Precision agriculture: A passion for Togolese ...  4 09 2024
# 1  China’s top nationalist influencer Hu Xijin si...  4 09 2024
# 2  Georgian Dream Party vows to ban opposition if...  3 09 2024
# 3  Pacific leaders’ statement removes Taiwan refe...  3 09 2024
# 4  Mongolia’s new minister is determined to refor...  3 09 2024

# %%
# Convert the date column to a datetime data type with the `dayfirst=True` parameter
df.date = pd.to_datetime(df.date, dayfirst=True)

# %%
# Display the DataFrame
df
# Out:
#                                                 header       date
# 0    Precision agriculture: A passion for Togolese ... 2024-09-04
# 1    China’s top nationalist influencer Hu Xijin si... 2024-09-04
# 2    Georgian Dream Party vows to ban opposition if... 2024-09-03
# 3    Pacific leaders’ statement removes Taiwan refe... 2024-09-03
# 4    Mongolia’s new minister is determined to refor... 2024-09-03
# ..                                                 ...        ...
# 100  Two women athletes have just earned St. Lucia ... 2024-08-04
# 101  Vaping loopholes are endangering children and ... 2024-08-03
# 102                  Turkey blocks access to Instagram 2024-08-02
# 103               The Caribbean marks Emancipation Day 2024-08-02
# 104  How the war in Ukraine prompted an exodus of C... 2024-08-02
#
# [105 rows x 2 columns]

# %%
# Check the DataFrame information to ensure the date is saved as a datetime data type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   header  105 non-null    object
#  1   date    105 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), object(1)
# memory usage: 1.8+ KB

# %%
# Close the browser
browser.quit()
